# %% [markdown]
# # Cereal Ratings using a Neural Network

# %% [markdown]
# ## Loading the Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

from math import sqrt

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Loading the Data
#
# Load the German Credit data set into the environment

# %%
df = pd.read_csv("./cereals.csv")

# %% [markdown]
# and let's have a look at the structure

# %%
df
# Out:
#     calories  protein  fat  sodium  fiber     rating
# 0         70        4    1     130   10.0  68.402973
# 1        120        3    5      15    2.0  33.983679
# 2         70        4    1     260    9.0  59.425505
# 3         50        4    0     140   14.0  93.704912
# 4        110        2    2     180    1.5  29.509541
# ..       ...      ...  ...     ...    ...        ...
# 70       110        2    1     250    0.0  39.106174
# 71       110        1    1     140    0.0  27.753301
# 72       100        3    1     230    3.0  49.787445
# 73       100        3    1     200    3.0  51.592193
# 74       110        2    1     200    1.0  36.187559
#
# [75 rows x 6 columns]

# %%
df.dtypes
# Out:
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# rating      float64
# dtype: object

# %% [markdown]
# ## Prepare the Data
#
# Split the data into 80% to train and 20% to test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    df.drop(columns='rating'), df['rating'],
    test_size=0.2, random_state=0
)

# %% [markdown]
# ## Train the model

# %%
pipeline = Pipeline(steps=[
    ("preprocessor", StandardScaler()),
    ("classifier", MLPRegressor(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(3,), random_state=1,max_iter=1000))
])

pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('preprocessor', StandardScaler()),
#                 ('classifier',
#                  MLPRegressor(alpha=1e-05, hidden_layer_sizes=(3,),
#                               max_iter=1000, random_state=1, solver='lbfgs'))])

# %% [markdown]
# ## Make Predictions

# %%
pred_train = pipeline.predict(X_train)
pred_test = pipeline.predict(X_test)

# %%
sqrt(mean_squared_error(Y_test, pred_test))
# Out:
# 6.312642622850733

# %% [markdown]
# ## Tune the Hyperparameters

# %%
param_list = {
    "hidden_layer_sizes": [2,5,10],
    "activation": ["identity", "logistic", "tanh", "relu"],
    "alpha": [0.00005,0.0005]
}
gridCV = GridSearchCV(estimator=MLPRegressor(solver='lbfgs', max_iter=5000), param_grid=param_list)

# %%
gridCV.fit(X_train, Y_train)
# Out:
# /Users/dongyuangao/Library/CloudStorage/OneDrive-Personal/文档/学业/硕士hslu/Lectures Lessons Subjects/semester 2/Machine Learning 1/week5 ANN/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:602: ConvergenceWarning: lbfgs failed to converge after 5000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=5000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# GridSearchCV(estimator=MLPRegressor(max_iter=5000, solver='lbfgs'),
#              param_grid={'activation': ['identity', 'logistic', 'tanh', 'relu'],
#                          'alpha': [5e-05, 0.0005],
#                          'hidden_layer_sizes': [2, 5, 10]})

# %%
gridCV.best_estimator_
# Out:
# MLPRegressor(activation='identity', alpha=0.0005, hidden_layer_sizes=10,
#              solver='lbfgs')
